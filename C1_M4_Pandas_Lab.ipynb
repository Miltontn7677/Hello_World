# %% [markdown]
# <a href="https://colab.research.google.com/github/Miltontn7677/Hello_World/blob/master/C1_M4_Pandas_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas
#
# This section is all about the package, Pandas. Are you ready? Let's go!
#
# You will find some small tasks in sections below. Most codes are hidden and you can only see the output.
#
# > Try to figure out by yourself, or search for references. Being able to search and find information needed is an important skill that benefits you and your career for a long time.

# %% [markdown]
# ## Set up the environment

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Task: import pandas, and name it as pd

# %%
# Your code is here

# %% [markdown]
# ## Data Creation

# %% [markdown]
# ### Task
# Find the data [here](https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)) for the GDP (nomial). For the top **10** countries, create a dataframe that has the names of country, the GDP of the country in 2021 (reported in 2022) by IMF in dollars , the population of the country (you can find the data [here](https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population))

# %%
df = pd.DataFrame({
    'Country':['United States', 'China', 'Germany', 'Japan', 'India', 'United Kingdom', 'France', 'Brazil', 'Italy', 'Canada', 'Russia'],
    "GDP":[28781083,18532633, 4591100, 4110452, 3937011, 3495261, 3130014, 2331391,  2328028, 2242182, 2056844],
    'Population':[332943701, 1425881285, 125502000, 83695430,1417945080, 67081234, 67874000, 38856839, 58906742, 214956683, 145805945] # Added the population for Russia
})
df1 = df.head(10)
df1
# Out:
#           Country       GDP  Population
# 0   United States  28781083   332943701
# 1           China  18532633  1425881285
# 2         Germany   4591100   125502000
# 3           Japan   4110452    83695430
# 4           India   3937011  1417945080
# 5  United Kingdom   3495261    67081234
# 6          France   3130014    67874000
# 7          Brazil   2331391    38856839
# 8           Italy   2328028    58906742
# 9          Canada   2242182   214956683

# %% [markdown]
# ## Data Accessing

# %% [markdown]
# ### Task: List the countries and their GDP

# %%
# Your code is here

# %% [markdown]
# ### Task: List the countries and their population

# %%
# Your code is here

# %% [markdown]
# ### Task: List the first country with its GDP and population

# %%
# Your code is here

# %% [markdown]
# ## Data Selection

# %% [markdown]
# ### Task: Show the countries whose GDP is more than 5 trillion dollars
# > (Hint: the data source has US$ Million as a unit, hence you need to choose GDP > 5,000,000 unit)

# %%
# Your code is here
df2 = df1[df1['GDP'] > 5000000]
df2
# Out:
#          Country       GDP  Population
# 0  United States  28781083   332943701
# 1          China  18532633  1425881285

# %% [markdown]
# ### Task: Show the countries whose GDP is more than 3 trillion dollars

# %%
# Your code is here
df3= df1[df1['GDP'] > 3000000]
df3
# Out:
#           Country       GDP  Population
# 0   United States  28781083   332943701
# 1           China  18532633  1425881285
# 2         Germany   4591100   125502000
# 3           Japan   4110452    83695430
# 4           India   3937011  1417945080
# 5  United Kingdom   3495261    67081234
# 6          France   3130014    67874000

# %% [markdown]
# ### Task: Show the countries whose pupulation is more than 1 billion

# %%
# Your code is here
df4 = df1[df1['Population'] > 1000000000]
df4
# Out:
#   Country       GDP  Population
# 1   China  18532633  1425881285
# 4   India   3937011  1417945080

# %% [markdown]
# ### Task: Show the countries whose pupulation is less than 300 million

# %%
# Your code is here
df5 = df1[df1['Population'] < 300000000]
df5
# Out:
#           Country      GDP  Population
# 2         Germany  4591100   125502000
# 3           Japan  4110452    83695430
# 5  United Kingdom  3495261    67081234
# 6          France  3130014    67874000
# 7          Brazil  2331391    38856839
# 8           Italy  2328028    58906742
# 9          Canada  2242182   214956683

# %% [markdown]
# ### Task: Show the countries whose pupulation is between 300 million and 500 million

# %%
# Your code is here
df6 = df1[(df1['Population'] > 300000000) & (df1['Population'] < 500000000)]
df6
# Out:
#          Country       GDP  Population
# 0  United States  28781083   332943701

# %% [markdown]
# ## Data Manipulation

# %% [markdown]
# ### Task: Create a new column, called "GDP per capita", based on the column "GDP" and the column "Population"

# %%
# Your code is here
df1['GDP per capita'] = df1['GDP'] / df1['Population']
df1
# Out:
# <ipython-input-22-23a5af1468fa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['GDP per capita'] = df1['GDP'] / df1['Population']
#           Country       GDP  Population  GDP per capita
# 0   United States  28781083   332943701        0.086444
# 1           China  18532633  1425881285        0.012997
# 2         Germany   4591100   125502000        0.036582
# 3           Japan   4110452    83695430        0.049112
# 4           India   3937011  1417945080        0.002777
# 5  United Kingdom   3495261    67081234        0.052105
# 6          France   3130014    67874000        0.046115
# 7          Brazil   2331391    38856839        0.060000
# 8           Italy   2328028    58906742        0.039521
# 9          Canada   2242182   214956683        0.010431

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# ### Task: With the three numeric columns, show the statsitics of each:
#
#
# 1.   Count
# 1.   Max
# 1.   Min
# 1.   Mean
# 1.   Median
# 1.   Quantiles
# 1.   25% Quantile
# 1.   50% Quantile
# 1.   75% QUantile
# 1.   Variance
# 1.   Std
# 1.   Total

# %%
# Your code is here
df1.describe()
# Out:
#                 GDP    Population  GDP per capita
# count  1.000000e+01  1.000000e+01       10.000000
# mean   7.347916e+06  3.833643e+08        0.039608
# std    8.964504e+06  5.545693e+08        0.025437
# min    2.242182e+06  3.885684e+07        0.002777
# 25%    2.531047e+06  6.727943e+07        0.018893
# 50%    3.716136e+06  1.045987e+08        0.042818
# 75%    4.470938e+06  3.034469e+08        0.051357
# max    2.878108e+07  1.425881e+09        0.086444
